# %%
from ultralytics import YOLO

# Initialize YOLO with pretrained weights
model = YOLO("yolov8n.pt")

# Train vest model
model.train(
    data=r"D:\Sainath_Backup\Desktop\UCHIT TECHNOLOGIES\VMS\Safety Vests.v9i.yolov5pytorch\vest.yaml",
    epochs=100,        # adjust as needed
    batch=4,           # safe for 4GB GPU
    device=0,          # use GPU
    workers=0
)

# Save trained model
model.save("vest_model.pt")
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolov8n.pt to 'yolov8n.pt': 100% ━━━━━━━━━━━━ 6.2/6.2MB 1.8MB/s 3.4s5s2s
# New https://pypi.org/project/ultralytics/8.3.189 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.187  Python-3.11.0 torch-2.1.0+cu121 CUDA:0 (NVIDIA GeForce RTX 3050 Laptop GPU, 4096MiB)
# engine\trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=4, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=D:\Sainath_Backup\Desktop\UCHIT TECHNOLOGIES\VMS\Safety Vests.v9i.yolov5pytorch\vest.yaml, degrees=0.0, deterministic=True, device=0, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=100, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolov8n.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=train, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=None, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=runs\detect\train, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=0, workspace=None
# Overriding model.yaml nc=80 with nc=2
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    460288  ultralytics.nn.modules.block.C2f             [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1     37248  ultralytics.nn.modules.block.C2f             [192, 64, 1]
#  16                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    123648  ultralytics.nn.modules.block.C2f             [192, 128, 1]
#  19                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  22        [15, 18, 21]  1    751702  ultralytics.nn.modules.head.Detect           [2, [64, 128, 256]]
# Model summary: 129 layers, 3,011,238 parameters, 3,011,222 gradients, 8.2 GFLOPs
#
# Transferred 319/355 items from pretrained weights
# Freezing layer 'model.22.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolo11n.pt to 'yolo11n.pt': 100% ━━━━━━━━━━━━ 5.4/5.4MB 1.8MB/s 2.9s9s6s
# AMP: checks passed
# train: Fast image access  (ping: 0.60.4 ms, read: 96.523.2 MB/s, size: 48.7 KB)
# train: Scanning D:\Sainath_Backup\Desktop\UCHIT TECHNOLOGIES\VMS\Safety Vests.v9i.yolov5pytorch\train\labels... 13635 images, 6 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 13635/13635 1350.0it/s 10.1s
# train: New cache created: D:\Sainath_Backup\Desktop\UCHIT TECHNOLOGIES\VMS\Safety Vests.v9i.yolov5pytorch\train\labels.cache
# val: Fast image access  (ping: 0.10.0 ms, read: 69.725.7 MB/s, size: 39.4 KB)
# val: Scanning D:\Sainath_Backup\Desktop\UCHIT TECHNOLOGIES\VMS\Safety Vests.v9i.yolov5pytorch\valid\labels... 778 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 778/778 1194.5it/s 0.7s
# val: New cache created: D:\Sainath_Backup\Desktop\UCHIT TECHNOLOGIES\VMS\Safety Vests.v9i.yolov5pytorch\valid\labels.cache
# Plotting labels to runs\detect\train\labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: SGD(lr=0.01, momentum=0.9) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.0005), 63 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 0 dataloader workers
# Logging results to runs\detect\train
# Starting training for 100 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       1/100     0.793G      1.447      2.229      1.537         17        640: 100% ━━━━━━━━━━━━ 3409/3409 4.5it/s 12:32
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 98/98 6.2it/s 15.8s
#                    all        778       1646      0.722      0.669      0.716      0.351
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       2/100     0.793G      1.422      1.692      1.479         13        640: 100% ━━━━━━━━━━━━ 3409/3409 4.9it/s 11:36
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 98/98 6.6it/s 14.8s
#                    all        778       1646      0.727      0.673      0.724      0.375
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       3/100     0.793G      1.487      1.647      1.545         10        640: 100% ━━━━━━━━━━━━ 3409/3409 4.9it/s 11:36
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 98/98 6.8it/s 14.4s
#                    all        778       1646      0.763      0.596       0.69      0.327
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       4/100     0.793G       1.52      1.627      1.585         12        640: 100% ━━━━━━━━━━━━ 3409/3409 5.0it/s 11:22
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 98/98 7.2it/s 13.5s
#                    all        778       1646      0.701       0.71      0.723      0.373
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       5/100     0.793G      1.469      1.495      1.554         22        640: 100% ━━━━━━━━━━━━ 3409/3409 5.1it/s 11:12
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 98/98 6.7it/s 14.6s
#                    all        778       1646      0.806      0.726      0.788      0.404
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       6/100     0.793G      1.436      1.398      1.528         12        640: 100% ━━━━━━━━━━━━ 3409/3409 5.0it/s 11:25
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 98/98 6.8it/s 14.5s
#                    all        778       1646      0.828      0.737      0.812      0.428
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       7/100     0.793G      1.397      1.333      1.495         15        640: 100% ━━━━━━━━━━━━ 3409/3409 5.0it/s 11:27
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 98/98 7.1it/s 13.8s
#                    all        778       1646      0.811      0.742      0.815      0.447
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       8/100     0.793G      1.383      1.295      1.487          8        640: 100% ━━━━━━━━━━━━ 3409/3409 5.0it/s 11:24
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 98/98 6.5it/s 15.2s
#                    all        778       1646      0.811      0.755      0.817      0.458
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       9/100     0.793G      1.361      1.243      1.466          3        640: 100% ━━━━━━━━━━━━ 3409/3409 5.0it/s 11:26
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 98/98 6.7it/s 14.6s
#                    all        778       1646      0.801      0.755      0.817      0.457
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      10/100     0.793G      1.339      1.204      1.458          8        640: 100% ━━━━━━━━━━━━ 3409/3409 4.9it/s 11:30
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 98/98 6.5it/s 15.1s
#                    all        778       1646      0.815      0.782      0.843      0.501
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      11/100     0.793G      1.329       1.18      1.438         10        640: 100% ━━━━━━━━━━━━ 3409/3409 4.7it/s 11:59
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 98/98 5.6it/s 17.4s
#                    all        778       1646      0.821      0.768      0.831      0.481
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      12/100     0.793G      1.312      1.139       1.43          8        640: 100% ━━━━━━━━━━━━ 3409/3409 4.2it/s 13:35
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 98/98 6.3it/s 15.6s
#                    all        778       1646      0.831      0.748       0.83      0.482
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      13/100     0.793G      1.292      1.118      1.419         13        640: 100% ━━━━━━━━━━━━ 3409/3409 4.7it/s 11:59
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 98/98 6.5it/s 15.1s
#                    all        778       1646      0.824      0.784      0.853        0.5
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      14/100     0.793G      1.286      1.088      1.413          8        640: 100% ━━━━━━━━━━━━ 3409/3409 4.9it/s 11:42
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 98/98 6.5it/s 15.0s
#                    all        778       1646      0.853      0.795       0.86      0.502
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      15/100     0.793G      1.269      1.076      1.398         15        640: 100% ━━━━━━━━━━━━ 3409/3409 4.8it/s 11:49
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 98/98 6.6it/s 14.8s
#                    all        778       1646      0.851      0.786      0.854      0.506
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      16/100     0.793G      1.256      1.045      1.392          8        640: 100% ━━━━━━━━━━━━ 3409/3409 4.9it/s 11:38
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 98/98 7.0it/s 14.1s
#                    all        778       1646      0.841      0.794      0.853      0.506
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      17/100     0.793G      1.247      1.033      1.379          9        640: 100% ━━━━━━━━━━━━ 3409/3409 5.0it/s 11:24
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 98/98 6.6it/s 14.7s
#                    all        778       1646       0.83      0.804      0.862      0.501
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      18/100     0.793G      1.243      1.024      1.377         23        640: 100% ━━━━━━━━━━━━ 3409/3409 4.9it/s 11:38
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 98/98 6.6it/s 14.9s
#                    all        778       1646      0.842      0.795      0.858      0.515
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      19/100     0.793G      1.234      1.002      1.371         14        640: 100% ━━━━━━━━━━━━ 3409/3409 4.9it/s 11:40
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 98/98 6.6it/s 14.9s
#                    all        778       1646      0.846      0.809      0.866      0.518
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      20/100     0.793G      1.226     0.9874       1.36         12        640: 100% ━━━━━━━━━━━━ 3409/3409 4.9it/s 11:43
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 98/98 6.7it/s 14.7s
#                    all        778       1646      0.842      0.808      0.864      0.516
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      21/100     0.793G      1.209     0.9755       1.35         13        640: 100% ━━━━━━━━━━━━ 3409/3409 4.8it/s 11:53
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 98/98 6.6it/s 14.7s
#                    all        778       1646      0.858       0.82       0.87      0.533
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      22/100     0.793G      1.205     0.9694      1.351         11        640: 100% ━━━━━━━━━━━━ 3409/3409 4.8it/s 11:50
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 98/98 6.5it/s 15.0s
#                    all        778       1646      0.841      0.822      0.871       0.53
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      23/100     0.793G        1.2      0.959      1.342         10        640: 100% ━━━━━━━━━━━━ 3409/3409 4.9it/s 11:34
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 98/98 7.2it/s 13.6s
#                    all        778       1646      0.874      0.803      0.878      0.527
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      24/100     0.793G      1.195     0.9495      1.343         21        640: 100% ━━━━━━━━━━━━ 3409/3409 4.9it/s 11:37
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 98/98 6.4it/s 15
54
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 98/98 5.6it/s 17.6s
#                    all        778       1646       0.87      0.859      0.894      0.553
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      86/100     0.793G     0.8933      0.594      1.134         11        640: 100% ━━━━━━━━━━━━ 3409/3409 4.4it/s 12:56
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 98/98 5.6it/s 17.5s
#                    all        778       1646      0.871      0.859      0.894      0.552
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      87/100     0.793G     0.8866     0.5901      1.133         10        640: 100% ━━━━━━━━━━━━ 3409/3409 4.3it/s 13:11
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 98/98 5.2it/s 18.9s
#                    all        778       1646      0.872      0.859      0.894      0.552
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      88/100     0.793G     0.8857      0.585       1.13          9        640: 100% ━━━━━━━━━━━━ 3409/3409 4.1it/s 14:01
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 98/98 5.0it/s 19.6s
#                    all        778       1646      0.873      0.858      0.894      0.552
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      89/100     0.793G     0.8789     0.5859      1.128         13        640: 100% ━━━━━━━━━━━━ 3409/3409 4.2it/s 13:28
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 98/98 5.2it/s 19.0s
#                    all        778       1646      0.876      0.855      0.893      0.551
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      90/100     0.793G     0.8773     0.5836      1.127         16        640: 100% ━━━━━━━━━━━━ 3409/3409 4.1it/s 13:42
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 98/98 2.9it/s 33.6s
#                    all        778       1646      0.876      0.855      0.894      0.551
# Closing dataloader mosaic
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      91/100     0.793G     0.8029     0.4291      1.084          6        640: 100% ━━━━━━━━━━━━ 3409/3409 0.37it/s 2:33:04
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 98/98 6.3it/s 15.5s
#                    all        778       1646      0.875      0.855      0.893      0.552
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      92/100     0.793G     0.7844     0.4171      1.076          3        640: 100% ━━━━━━━━━━━━ 3409/3409 5.2it/s 10:55
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 98/98 6.2it/s 15.7s
#                    all        778       1646      0.872      0.856      0.894      0.553
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      93/100     0.793G     0.7781     0.4091      1.069          6        640: 100% ━━━━━━━━━━━━ 3409/3409 5.4it/s 10:30
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 98/98 6.4it/s 15.4s
#                    all        778       1646       0.87      0.855      0.893      0.553
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      94/100     0.793G      0.766     0.4033      1.063          4        640: 100% ━━━━━━━━━━━━ 3409/3409 5.4it/s 10:35
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 98/98 6.4it/s 15.3s
#                    all        778       1646       0.87      0.855      0.894      0.553
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      95/100     0.793G     0.7599        0.4      1.062          6        640: 100% ━━━━━━━━━━━━ 3409/3409 5.3it/s 10:39
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 98/98 6.2it/s 15.7s
#                    all        778       1646      0.864      0.859      0.894      0.553
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      96/100     0.793G     0.7527     0.3942      1.052          4        640: 100% ━━━━━━━━━━━━ 3409/3409 5.3it/s 10:43
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 98/98 6.3it/s 15.7s
#                    all        778       1646      0.863      0.859      0.894      0.552
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      97/100     0.795G     0.7467     0.3906      1.049         10        640: 100% ━━━━━━━━━━━━ 3409/3409 5.5it/s 10:23
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 98/98 6.6it/s 14.9s
#                    all        778       1646      0.863      0.861      0.894      0.552
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      98/100     0.795G      0.742     0.3897      1.046          7        640: 100% ━━━━━━━━━━━━ 3409/3409 5.6it/s 10:12
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 98/98 6.7it/s 14.5s
#                    all        778       1646      0.865      0.857      0.894      0.551
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      99/100     0.795G     0.7365     0.3844      1.045          4        640: 100% ━━━━━━━━━━━━ 3409/3409 5.5it/s 10:20
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 98/98 6.2it/s 15.8s
#                    all        778       1646      0.865      0.857      0.895      0.551
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     100/100     0.795G     0.7333      0.384      1.039          3        640: 100% ━━━━━━━━━━━━ 3409/3409 5.3it/s 10:43
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 98/98 6.2it/s 15.9s
#                    all        778       1646      0.855      0.868      0.894      0.551
#
# 100 epochs completed in 25.943 hours.
# Optimizer stripped from runs\detect\train\weights\last.pt, 6.3MB
# Optimizer stripped from runs\detect\train\weights\best.pt, 6.3MB
#
# Validating runs\detect\train\weights\best.pt...
# Ultralytics 8.3.187  Python-3.11.0 torch-2.1.0+cu121 CUDA:0 (NVIDIA GeForce RTX 3050 Laptop GPU, 4096MiB)
# Model summary (fused): 72 layers, 3,006,038 parameters, 0 gradients, 8.1 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 98/98 6.8it/s 14.4s
#                    all        778       1646      0.875      0.858        0.9      0.563
#                no-vest        188        359      0.832      0.857      0.878       0.48
#                   vest        609       1287      0.918      0.859      0.922      0.647
# Speed: 0.4ms preprocess, 4.6ms inference, 0.0ms loss, 1.5ms postprocess per image
# Results saved to runs\detect\train

# %%
from ultralytics import YOLO
import cv2
import os
import pygame
import time

# Initialize pygame mixer for alert sound
pygame.mixer.init()
alert_sound = r"D:\Sainath_Backup\Desktop\UCHIT TECHNOLOGIES\VMS\Safety Vests.v9i.yolov5pytorch\vestalert.mp3"

# Load trained vest model
model = YOLO(r"D:\Sainath_Backup\Desktop\UCHIT TECHNOLOGIES\VMS\Safety Vests.v9i.yolov5pytorch\vest_model.pt")

# Class names
class_names = ['no-vest', 'vest']

# Video path
video_path = r"D:\Sainath_Backup\Desktop\UCHIT TECHNOLOGIES\VMS\Safety Vests.v9i.yolov5pytorch\41501-429661287_small.mp4"

# Output video path
save_path = os.path.join(os.path.dirname(video_path), "vest_detection_output.mp4")

# Folder for saving "no-vest" screenshots
screenshot_dir = os.path.join(os.path.dirname(video_path), "novestsamples")
os.makedirs(screenshot_dir, exist_ok=True)

# Video setup
cap = cv2.VideoCapture(video_path)
fps = int(cap.get(cv2.CAP_PROP_FPS))
width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
fourcc = cv2.VideoWriter_fourcc(*'mp4v')
out = cv2.VideoWriter(save_path, fourcc, fps, (width, height))

frame_no = 0
screenshot_count = 0

# Track individual persons without vests
class PersonTracker:
    def __init__(self):
        self.persons = {}  # person_id: {'max_conf': float, 'best_frame': frame, 'alerted': bool, 'last_seen': frame_no}
        self.next_id = 1
        self.iou_threshold = 0.3  # For matching detections across frames
        self.max_frames_missing = 30  # Remove person if not seen for 30 frames
    
    def calculate_iou(self, box1, box2):
        """Calculate Intersection over Union (IoU) of two bounding boxes"""
        x1_inter = max(box1[0], box2[0])
        y1_inter = max(box1[1], box2[1])
        x2_inter = min(box1[2], box2[2])
        y2_inter = min(box1[3], box2[3])
        
        if x2_inter <= x1_inter or y2_inter <= y1_inter:
            return 0.0
        
        inter_area = (x2_inter - x1_inter) * (y2_inter - y1_inter)
        box1_area = (box1[2] - box1[0]) * (box1[3] - box1[1])
        box2_area = (box2[2] - box2[0]) * (box2[3] - box2[1])
        union_area = box1_area + box2_area - inter_area
        
        return inter_area / union_area if union_area > 0 else 0
    
    def update(self, no_vest_detections, frame, current_frame_no):
        """Update tracker with new detections"""
        alerts_triggered = []
        
        # Mark all persons as not seen this frame
        for person_id in self.persons:
            self.persons[person_id]['seen_this_frame'] = False
        
        # Match new detections with existing persons
        for detection in no_vest_detections:
            x1, y1, x2, y2, conf = detection
            current_box = [x1, y1, x2, y2]
            
            # Find best matching existing person
            best_match_id = None
            best_iou = 0
            
            for person_id, person_data in self.persons.items():
                if 'last_box' in person_data:
                    iou = self.calculate_iou(current_box, person_data['last_box'])
                    if iou > best_iou and iou > self.iou_threshold:
                        best_iou = iou
                        best_match_id = person_id
            
            if best_match_id is not None:
                # Update existing person
                person = self.persons[best_match_id]
                person['last_seen'] = current_frame_no
                person['last_box'] = current_box
                person['seen_this_frame'] = True
                
                # Check if this is a new highest confidence
                if conf > person['max_conf']:
                    person['max_conf'] = conf
                    person['best_frame'] = frame.copy()
                    
                    # Trigger alert if not already alerted for this person
                    if not person['alerted']:
                        person['alerted'] = True
                        alerts_triggered.append((best_match_id, conf, frame.copy()))
            else:
                # Create new person
                person_id = self.next_id
                self.next_id += 1
                
                self.persons[person_id] = {
                    'max_conf': conf,
                    'best_frame': frame.copy(),
                    'alerted': True,  # Alert immediately for new detection
                    'last_seen': current_frame_no,
                    'last_box': current_box,
                    'seen_this_frame': True
                }
                
                alerts_triggered.append((person_id, conf, frame.copy()))
        
        # Remove persons not seen for too long
        to_remove = []
        for person_id, person_data in self.persons.items():
            if not person_data['seen_this_frame']:
                if current_frame_no - person_data['last_seen'] > self.max_frames_missing:
                    to_remove.append(person_id)
        
        for person_id in to_remove:
            del self.persons[person_id]
        
        return alerts_triggered

# Initialize tracker
tracker = PersonTracker()

# Track last alert time to prevent audio overlap
last_alert_time = 0
min_alert_interval = 2.0  # Minimum 2 seconds between alerts

while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break

    # Run YOLO detection
    results = model(frame, conf=0.25, verbose=False)

    no_vest_detections = []
    current_time = time.time()

    for r in results:
        for box in r.boxes:
            cls_id = int(box.cls[0])
            conf = float(box.conf[0])
            x1, y1, x2, y2 = map(int, box.xyxy[0])

            if class_names[cls_id] == "no-vest":
                no_vest_detections.append((x1, y1, x2, y2, conf))
                color = (0, 0, 255)  # Red
            else:
                color = (0, 255, 0)  # Green

            # Draw box
            cv2.rectangle(frame, (x1, y1), (x2, y2), color, 2)
            label = f"{class_names[cls_id]} {conf:.2f}"
            cv2.putText(frame, label, (x1, y1 - 10),
                        cv2.FONT_HERSHEY_SIMPLEX, 0.7, color, 2)

    # Update tracker and get alerts
    alerts = tracker.update(no_vest_detections, frame, frame_no)
    
    # Process alerts
    for person_id, conf, alert_frame in alerts:
        # Play alert sound (with timing control to prevent overlap)
        if current_time - last_alert_time >= min_alert_interval:
            try:
                pygame.mixer.music.load(alert_sound)
                pygame.mixer.music.play()
                last_alert_time = current_time
            except pygame.error as e:
                print(f"Audio error: {e}")

        # Save screenshot of the detection with highest confidence
        screenshot_count += 1
        screenshot_path = os.path.join(screenshot_dir, f"novestsample_person{person_id}_conf{conf:.2f}_{screenshot_count}.jpg")
        cv2.imwrite(screenshot_path, alert_frame)
        print(f"⚠️ Person {person_id} without vest detected! Confidence: {conf:.2f} - Screenshot saved: {screenshot_path}")

    # Add tracking info to display
    if tracker.persons:
        y_offset = 30
        for person_id, person_data in tracker.persons.items():
            info_text = f"Person {person_id}: Max Conf {person_data['max_conf']:.2f}"
            cv2.putText(frame, info_text, (10, y_offset), cv2.FONT_HERSHEY_SIMPLEX, 0.6, (255, 255, 0), 2)
            y_offset += 25

    # Show video live
    cv2.imshow("Vest Detection", frame)

    # Save to output video
    out.write(frame)

    # Quit on 'q'
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

    frame_no += 1

# Save final screenshots for all tracked persons with their highest confidence frames
print("\n📸 Saving final best screenshots for all tracked persons:")
for person_id, person_data in tracker.persons.items():
    final_screenshot_path = os.path.join(screenshot_dir, f"BEST_novestsample_person{person_id}_conf{person_data['max_conf']:.2f}.jpg")
    cv2.imwrite(final_screenshot_path, person_data['best_frame'])
    print(f"💾 Person {person_id} best screenshot (conf: {person_data['max_conf']:.2f}) saved: {final_screenshot_path}")

cap.release()
out.release()
cv2.destroyAllWindows()

print(f"\n✅ Processed video saved at: {save_path}")
print(f"📸 Screenshots saved in: {screenshot_dir}")
print(f"👥 Total persons without vest tracked: {len(tracker.persons)}")
print(f"🔊 Total alerts triggered: {screenshot_count}")
# Out:
# c:\Users\nikam\AppData\Local\Programs\Python\Python311\Lib\site-packages\pygame\pkgdata.py:25: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import resource_stream, resource_exists
# pygame 2.6.1 (SDL 2.28.4, Python 3.11.0)
# Hello from the pygame community. https://www.pygame.org/contribute.html
# ⚠️ Person 1 without vest detected! Confidence: 0.56 - Screenshot saved: D:\Sainath_Backup\Desktop\UCHIT TECHNOLOGIES\VMS\Safety Vests.v9i.yolov5pytorch\novestsamples\novestsample_person1_conf0.56_1.jpg
# ⚠️ Person 2 without vest detected! Confidence: 0.32 - Screenshot saved: D:\Sainath_Backup\Desktop\UCHIT TECHNOLOGIES\VMS\Safety Vests.v9i.yolov5pytorch\novestsamples\novestsample_person2_conf0.32_2.jpg
# ⚠️ Person 3 without vest detected! Confidence: 0.41 - Screenshot saved: D:\Sainath_Backup\Desktop\UCHIT TECHNOLOGIES\VMS\Safety Vests.v9i.yolov5pytorch\novestsamples\novestsample_person3_conf0.41_3.jpg
# ⚠️ Person 4 without vest detected! Confidence: 0.25 - Screenshot saved: D:\Sainath_Backup\Desktop\UCHIT TECHNOLOGIES\VMS\Safety Vests.v9i.yolov5pytorch\novestsamples\novestsample_person4_conf0.25_4.jpg
# ⚠️ Person 5 without vest detected! Confidence: 0.28 - Screenshot saved: D:\Sainath_Backup\Desktop\UCHIT TECHNOLOGIES\VMS\Safety Vests.v9i.yolov5pytorch\novestsamples\novestsample_person5_conf0.28_5.jpg
#
# 📸 Saving final best screenshots for all tracked persons:
# 💾 Person 1 best screenshot (conf: 0.81) saved: D:\Sainath_Backup\Desktop\UCHIT TECHNOLOGIES\VMS\Safety Vests.v9i.yolov5pytorch\novestsamples\BEST_novestsample_person1_conf0.81.jpg
# 💾 Person 3 best screenshot (conf: 0.79) saved: D:\Sainath_Backup\Desktop\UCHIT TECHNOLOGIES\VMS\Safety Vests.v9i.yolov5pytorch\novestsamples\BEST_novestsample_person3_conf0.79.jpg
# 💾 Person 5 best screenshot (conf: 0.34) saved: D:\Sainath_Backup\Desktop\UCHIT TECHNOLOGIES\VMS\Safety Vests.v9i.yolov5pytorch\novestsamples\BEST_novestsample_person5_conf0.34.jpg
#
# ✅ Processed video saved at: D:\Sainath_Backup\Desktop\UCHIT TECHNOLOGIES\VMS\Safety Vests.v9i.yolov5pytorch\vest_detection_output.mp4
# 📸 Screenshots saved in: D:\Sainath_Backup\Desktop\UCHIT TECHNOLOGIES\VMS\Safety Vests.v9i.yolov5pytorch\novestsamples
# 👥 Total persons without vest tracked: 3
# 🔊 Total alerts triggered: 5
